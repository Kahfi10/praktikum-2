# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
import sklearn
warnings.filterwarnings("ignore")

# %%
df= pd.read_csv("preferensi_minuman_dataset.csv")

# %%
df.describe()
# Out:
#              usia  waktu_tidur  jumlah_kafein_perhari   jam_aktif  \
# count  100.000000    100.00000             100.000000  100.000000
# mean    38.270000      6.38500             257.000000   11.870000
# std     12.335262      1.42909             142.428646    3.907142
# min     18.000000      4.00000               1.000000    6.000000
# 25%     27.750000      5.20000             137.750000    8.000000
# 50%     38.500000      6.45000             257.500000   12.000000
# 75%     47.250000      7.60000             385.750000   15.000000
# max     60.000000      8.90000             499.000000   18.000000
#
#        jenis_minuman_favorit 0=Teh 1=Coffee
# count                            100.000000
# mean                               0.260000
# std                                0.440844
# min                                0.000000
# 25%                                0.000000
# 50%                                0.000000
# 75%                                1.000000
# max                                1.000000

# %%
start_col = 0
end_col = 3

x = df.iloc[:, start_col:end_col+1]
y = df.iloc[:, 4]

# %%
y
# Out:
# 0     0
# 1     0
# 2     1
# 3     1
# 4     0
#      ..
# 95    0
# 96    0
# 97    1
# 98    0
# 99    1
# Name: jenis_minuman_favorit 0=Teh 1=Coffee, Length: 100, dtype: int64

# %%
x
# Out:
#     usia  waktu_tidur  jumlah_kafein_perhari  jam_aktif
# 0     56          8.3                    475          6
# 1     46          7.1                    440         10
# 2     32          5.7                    472         17
# 3     60          4.3                    433         18
# 4     25          5.6                    150          8
# ..   ...          ...                    ...        ...
# 95    22          4.9                    225         10
# 96    59          7.5                    276          6
# 97    56          5.9                    285         13
# 98    58          8.7                     96         10
# 99    45          4.7                    283         17
#
# [100 rows x 4 columns]

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y, random_state=0, test_size=0.1)

# %%
from sklearn.tree import DecisionTreeClassifier
clf=DecisionTreeClassifier()
clf.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
import sklearn.metrics


y_predict = clf.predict(x_test)
akurasi = sklearn.metrics.accuracy_score(y_test, y_predict)

# %%
print(x_test)
print(akurasi)
# Out:
#     usia  waktu_tidur  jumlah_kafein_perhari  jam_aktif
# 26    42          6.1                    232         18
# 86    18          5.6                    157         15
# 2     32          5.7                    472         17
# 55    19          5.6                    365         15
# 75    41          5.2                    400         17
# 93    52          5.1                    282         16
# 16    39          6.6                    368         14
# 73    33          6.4                    134          8
# 54    21          8.7                    383         18
# 95    22          4.9                    225         10
# 0.9

# %%
df=pd.read_csv("preferensi_minuman_dataset.csv")

# %%
df
# Out:
#     usia  waktu_tidur  jumlah_kafein_perhari  jam_aktif  \
# 0     56          8.3                    475          6
# 1     46          7.1                    440         10
# 2     32          5.7                    472         17
# 3     60          4.3                    433         18
# 4     25          5.6                    150          8
# ..   ...          ...                    ...        ...
# 95    22          4.9                    225         10
# 96    59          7.5                    276          6
# 97    56          5.9                    285         13
# 98    58          8.7                     96         10
# 99    45          4.7                    283         17
#
#     jenis_minuman_favorit 0=Teh 1=Coffee
# 0                                      0
# 1                                      0
# 2                                      1
# 3                                      1
# 4                                      0
# ..                                   ...
# 95                                     0
# 96                                     0
# 97                                     1
# 98                                     0
# 99                                     1
#
# [100 rows x 5 columns]

# %%
x = df.iloc[:, start_col:end_col+1]
nama = df.iloc[:, 0]

# %%
x
# Out:
#     usia  waktu_tidur  jumlah_kafein_perhari  jam_aktif
# 0     56          8.3                    475          6
# 1     46          7.1                    440         10
# 2     32          5.7                    472         17
# 3     60          4.3                    433         18
# 4     25          5.6                    150          8
# ..   ...          ...                    ...        ...
# 95    22          4.9                    225         10
# 96    59          7.5                    276          6
# 97    56          5.9                    285         13
# 98    58          8.7                     96         10
# 99    45          4.7                    283         17
#
# [100 rows x 4 columns]

# %%
nama
# Out:
# 0     56
# 1     46
# 2     32
# 3     60
# 4     25
#       ..
# 95    22
# 96    59
# 97    56
# 98    58
# 99    45
# Name: usia, Length: 100, dtype: int64

# %%
y_predict = clf.predict(x)

# %%
nama= pd.DataFrame(nama)
nama=nama.reset_index(drop=True)
nama['ID']=nama.index+0
ey = pd.DataFrame(nama)

y_predict=pd.DataFrame(y_predict)
y_predict = y_predict.reset_index(drop=True)
y_predict['ID']=y_predict.index+0

ex = pd.DataFrame(y_predict)

# %%
ex.describe
# Out:
# <bound method NDFrame.describe of     0  ID
# 0   0   0
# 1   0   1
# 2   1   2
# 3   1   3
# 4   0   4
# .. ..  ..
# 95  0  95
# 96  0  96
# 97  1  97
# 98  0  98
# 99  1  99
#
# [100 rows x 2 columns]>

# %%
ey.describe
# Out:
# <bound method NDFrame.describe of     usia  ID
# 0     56   0
# 1     46   1
# 2     32   2
# 3     60   3
# 4     25   4
# ..   ...  ..
# 95    22  95
# 96    59  96
# 97    56  97
# 98    58  98
# 99    45  99
#
# [100 rows x 2 columns]>

# %%
result = pd.merge(ex, ey, on='ID', how='inner')

# %%
result.to_excel("hasil_prediksi3.xlsx", index=False)
